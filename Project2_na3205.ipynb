# %%
import pandas as pd
import numpy as np
import gurobipy as gp
from gurobipy import GRB
import time
from collections import defaultdict
import json
import math

# %%
nba_sc = pd.read_csv("games.csv")
nba_sc.head(2)
# Out:
#                 Date                Visitor  PTS             Home  PTS.1  \
# 0  Sat, Nov 01, 2025  Golden State Warriors  NaN   Boston Celtics    NaN
# 1  Sat, Nov 01, 2025     Los Angeles Lakers  NaN  New York Knicks    NaN
#
#   Attend.      LOG                  Arena Notes
# 0  19,000  7:30 PM              TD Garden   NaN
# 1  19,400  7:30 PM  Madison Square Garden   NaN

# %% [markdown]
# ## 1. Write codes that computes and prints, for each team i, the following information:

# %%
all_teams = sorted(set(nba_sc['Home'].unique()).union(set(nba_sc['Visitor'].unique())))

for team in all_teams:
    home_games = nba_sc[nba_sc['Home'] == team].copy()
    away_games = nba_sc[nba_sc['Visitor'] == team].copy()

    print(f"{team}")
        
#a) all the dates when team i played home
    home_dates = sorted(home_games["Date"].unique())
    print(f"\n(a) Dates for at Home Games ({len(home_dates)} games):")
    
    for date in home_dates:
        opponents = home_games[home_games["Date"] == date]["Visitor"].tolist()
        print(f"    {date}: vs {', '.join(opponents)}")
    
    #b): for each team j, the number of times team i played against team j at home
    matchups_at_home = home_games.groupby("Visitor").size().to_dict()
    print(f"\n(b) Home games vs:")
    for opponent in all_teams:
        if opponent != team:
            games = matchups_at_home.get(opponent, 0)
            if games >= 1:
                print(f"    vs {opponent:30s}")
    
    #c): for each team j, the number of times team i played against team j away (i.e., at j’s home)
    matchups_on_road = away_games.groupby("Home").size().to_dict()
    print(f"\n(c) Away games vs:")
    for opponent in all_teams:
        if opponent != team:
            games = matchups_on_road.get(opponent, 0)
            if games >= 1:
                print(f"    Visiting {opponent:30s}")
    
    #d) all the dates when team j played away.
    away_dates = sorted(away_games["Date"].unique())
    print(f"\n(d) Away games dates ({len(away_dates)} games):")
    for date in away_dates:
        opponents = away_games[away_games["Date"] == date]["Home"].tolist()
        print(f"{date}: Visiting the {', '.join(opponents)}")
# Out:
# Atlanta Hawks
#
# (a) Dates for at Home Games (10 games):
#     Fri, Nov 07, 2025: vs Golden State Warriors
#     Fri, Nov 28, 2025: vs Phoenix Suns
#     Mon, Nov 03, 2025: vs Toronto Raptors
#     Mon, Nov 17, 2025: vs Milwaukee Bucks
#     Sat, Nov 15, 2025: vs Boston Celtics
#     Sat, Nov 29, 2025: vs Dallas Mavericks
#     Sun, Nov 23, 2025: vs New York Knicks
#     Thu, Dec 25, 2025: vs Chicago Bulls
#     Thu, Nov 27, 2025: vs Los Angeles Lakers
#     Wed, Nov 19, 2025: vs Miami Heat
#
# (b) Home games vs:
#     vs Boston Celtics
#     vs Chicago Bulls
#     vs Dallas Mavericks
#     vs Golden State Warriors
#     vs Los Angeles Lakers
#     vs Miami Heat
#     vs Milwaukee Bucks
#     vs New York Knicks
#     vs Phoenix Suns
#     vs Toronto Raptors
#
# (c) Away games vs:
#     Visiting Brooklyn Nets
#     Visiting Chicago Bulls
#     Visiting Cleveland Cavaliers
#     Visiting Denver Nuggets
#     Visiting Houston Rockets
#     Visiting Philadelphia 76ers
#
# (d) Away games dates (6 games):
# Fri, Nov 21, 2025: Visiting the Philadelphia 76ers
# Mon, Dec 01, 2025: Visiting the Cleveland Cavaliers
# Sat, Nov 01, 2025: Visiting the Chicago Bulls
# Thu, Nov 13, 2025: Visiting the Houston Rockets
# Tue, Nov 11, 2025: Visiting the Denver Nuggets
# Wed, Nov 05, 2025: Visiting the Brooklyn Nets
# Boston Celtics
#
# (a) Dates for at Home Games (6 games):
#     Fri, Nov 07, 2025: vs Phoenix Suns
#     Fri, Nov 28, 2025: vs Philadelphia 76ers
#     Sat, Nov 01, 2025: vs Golden State Warriors
#     Sun, Nov 23, 2025: vs Miami Heat
#     Thu, Nov 13, 2025: vs Dallas Mavericks
#     Wed, Nov 19, 2025: vs Milwaukee Bucks
#
# (b) Home games vs:
#     vs Dallas Mavericks
#     vs Golden State Warriors
#     vs Miami Heat
#     vs Milwaukee Bucks
#     vs Philadelphia 76ers
#     vs Phoenix Suns
#
# (c) Away games vs:
#     Visiting Atlanta Hawks
#     Visiting Brooklyn Nets
#     Visiting Chicago Bulls
#     Visiting Cleveland Cavaliers
#     Visiting Denver Nuggets
#     Visiting Golden State Warriors
#     Visiting Houston Rockets
#     Visiting Los Angeles Lakers
#     Visiting New York Knicks
#     Visiting Toronto Raptors
#
# (d) Away games dates (10 games):
# Fri, Nov 21, 2025: Visiting the Chicago Bulls
# Mon, Dec 01, 2025: Visiting the New York Knicks
# Mon, Nov 03, 2025: Visiting the Los Angeles Lakers
# Mon, Nov 17, 2025: Visiting the Cleveland Cavaliers
# Sat, Nov 15, 2025: Visiting the Atlanta Hawks
# Sat, Nov 29, 2025: Visiting the Brooklyn Nets
# Thu, Dec 25, 2025: Visiting the Golden State Warriors
# Thu, Nov 27, 2025: Visiting the Toronto Raptors
# Tue, Nov 11, 2025: Visiting the Houston Rockets
# Wed, Nov 05, 2025: Visiting the Denver Nuggets
# Brooklyn Nets
#
# (a) Dates for at Home Games (7 games):
#     Fri, Nov 21, 2025: vs Dallas Mavericks
#     Mon, Dec 01, 2025: vs Golden State Warriors
#     Sat, Nov 01, 2025: vs Denver Nuggets
#     Sat, Nov 29, 2025: vs Boston Celtics
#     Thu, Nov 13, 2025: vs Philadelphia 76ers
#     Tue, Nov 11, 2025: vs Miami Heat
#     Wed, Nov 05, 2025: vs Atlanta Hawks
#
# (b) Home games vs:
#     vs Atlanta Hawks
#     vs Boston Celtics
#     vs Dallas Mavericks
#     vs Denver Nuggets
#     vs Golden State Warriors
#     vs Miami Heat
#     vs Philadelphia 76ers
#
# (c) Away games vs:
#     Visiting Chicago Bulls
#     Visiting Cleveland Cavaliers
#     Visiting Denver Nuggets
#     Visiting Houston Rockets
#     Visiting Los Angeles Lakers
#     Visiting Milwaukee Bucks
#     Visiting New York Knicks
#     Visiting Phoenix Suns
#     Visiting Toronto Raptors
#
# (d) Away games dates (9 games):
# Fri, Nov 07, 2025: Visiting the Milwaukee Bucks
# Fri, Nov 28, 2025: Visiting the Toronto Raptors
# Mon, Nov 03, 2025: Visiting the Houston Rockets
# Mon, Nov 17, 2025: Visiting the Los Angeles Lakers
# Sat, Nov 15, 2025: Visiting the New York Knicks
# Sun, Nov 23, 2025: Visiting the Cleveland Cavaliers
# Thu, Dec 25, 2025: Visiting the Denver Nuggets
# Thu, Nov 27, 2025: Visiting the Chicago Bulls
# Wed, Nov 19, 2025: Visiting the Phoenix Suns
# Chicago Bulls
#
# (a) Dates for at Home Games (9 games):
#     Fri, Nov 21, 2025: vs Boston Celtics
#     Fri, Nov 28, 2025: vs Golden State Warriors
#     Mon, Dec 01, 2025: vs Houston Rockets
#     Mon, Nov 03, 2025: vs Milwaukee Bucks
#     Sat, Nov 01, 2025: vs Atlanta Hawks
#     Sat, Nov 29, 2025: vs Denver Nuggets
#     Sun, Nov 23, 2025: vs Toronto Raptors
#     Thu, Nov 13, 2025: vs Los Angeles Lakers
#     Thu, Nov 27, 2025: vs Brooklyn Nets
#
# (b) Home games vs:
#     vs Atlanta Hawks
#     vs Boston Celtics
#     vs Brooklyn Nets
#     vs Denver Nuggets
#     vs Golden State Warriors
#     vs Houston Rockets
#     vs Los Angeles Lakers
#     vs Milwaukee Bucks
#     vs Toronto Raptors
#
# (c) Away games vs:
#     Visiting Atlanta Hawks
#     Visiting Cleveland Cavaliers
#     Visiting Dallas Mavericks
#     Visiting Miami Heat
#     Visiting New York Knicks
#     Visiting Philadelphia 76ers
#     Visiting Phoenix Suns
#
# (d) Away games dates (7 games):
# Fri, Nov 07, 2025: Visiting the Philadelphia 76ers
# Mon, Nov 17, 2025: Visiting the Dallas Mavericks
# Sat, Nov 15, 2025: Visiting the Phoenix Suns
# Thu, Dec 25, 2025: Visiting the Atlanta Hawks
# Tue, Nov 11, 2025: Visiting the New York Knicks
# Wed, Nov 05, 2025: Visiting the Miami Heat
# Wed, Nov 19, 2025: Visiting the Cleveland Cavaliers
# Cleveland Cavaliers
#
# (a) Dates for at Home Games (10 games):
#     Fri, Nov 07, 2025: vs New York Knicks
#     Fri, Nov 21, 2025: vs Toronto Raptors
#     Fri, Nov 28, 2025: vs Denver Nuggets
#     Mon, Dec 01, 2025: vs Atlanta Hawks
#     Mon, Nov 03, 2025: vs Miami Heat
#     Mon, Nov 17, 2025: vs Boston Celtics
#     Sat, Nov 29, 2025: vs Houston Rockets
#     Sun, Nov 23, 2025: vs Brooklyn Nets
#     Thu, Dec 25, 2025: vs Milwaukee Bucks
#     Wed, Nov 19, 2025: vs Chicago Bulls
#
# (b) Home games vs:
#     vs Atlanta Hawks
#     vs Boston Celtics
#     vs Brooklyn Nets
#     vs Chicago Bulls
#     vs Denver Nuggets
#     vs Houston Rockets
#     vs Miami Heat
#     vs Milwaukee Bucks
#     vs New York Knicks
#     vs Toronto Raptors
#
# (c) Away games vs:
#     Visiting Dallas Mavericks
#     Visiting Golden State Warriors
#     Visiting Los Angeles Lakers
#     Visiting Milwaukee Bucks
#     Visiting Philadelphia 76ers
#     Visiting Phoenix Suns
#
# (d) Away games dates (6 games):
# Sat, Nov 01, 2025: Visiting the Milwaukee Bucks
# Sat, Nov 15, 2025: Visiting the Dallas Mavericks
# Thu, Nov 13, 2025: Visiting the Phoenix Suns
# Thu, Nov 27, 2025: Visiting the Golden State Warriors
# Tue, Nov 11, 2025: Visiting the Los Angeles Lakers
# Wed, Nov 05, 2025: Visiting the Philadelphia 76ers
# Dallas Mavericks
#
# (a) Dates for at Home Games (9 games):
#     Fri, Nov 07, 2025: vs Los Angeles Lakers
#     Fri, Nov 28, 2025: vs Houston Rockets
#     Mon, Nov 03, 2025: vs Philadelphia 76ers
#     Mon, Nov 17, 2025: vs Chicago Bulls
#     Sat, Nov 15, 2025: vs Cleveland Cavaliers
#     Sun, Nov 23, 2025: vs Golden State Warriors
#     Thu, Dec 25, 2025: vs Miami Heat
#     Thu, Nov 27, 2025: vs Denver Nuggets
#     Wed, Nov 19, 2025: vs Toronto Raptors
#
# (b) Home games vs:
#     vs Chicago Bulls
#     vs Cleveland Cavaliers
#     vs Denver Nuggets
#     vs Golden State Warriors
#     vs Houston Rockets
#     vs Los Angeles Lakers
#     vs Miami Heat
#     vs Philadelphia 76ers
#     vs Toronto Raptors
#
# (c) Away games vs:
#     Visiting Atlanta Hawks
#     Visiting Boston Celtics
#     Visiting Brooklyn Nets
#     Visiting Miami Heat
#     Visiting Milwaukee Bucks
#     Visiting New York Knicks
#     Visiting Phoenix Suns
#
# (d) Away games dates (7 games):
# Fri, Nov 21, 2025: Visiting the Brooklyn Nets
# Mon, Dec 01, 2025: Visiting the Milwaukee Bucks
# Sat, Nov 01, 2025: Visiting the Miami Heat
# Sat, Nov 29, 2025: Visiting the Atlanta Hawks
# Thu, Nov 13, 2025: Visiting the Boston Celtics
# Tue, Nov 11, 2025: Visiting the Phoenix Suns
# Wed, Nov 05, 2025: Visiting the New York Knicks
# Denver Nuggets
#
# (a) Dates for at Home Games (8 games):
#     Fri, Nov 07, 2025: vs Houston Rockets
#     Fri, Nov 21, 2025: vs Los Angeles Lakers
#     Mon, Nov 17, 2025: vs Philadelphia 76ers
#     Sat, Nov 15, 2025: vs Miami Heat
#     Thu, Dec 25, 2025: vs Brooklyn Nets
#     Tue, Nov 11, 2025: vs Atlanta Hawks
#     Wed, Nov 05, 2025: vs Boston Celtics
#     Wed, Nov 19, 2025: vs New York Knicks
#
# (b) Home games vs:
#     vs Atlanta Hawks
#     vs Boston Celtics
#     vs Brooklyn Nets
#     vs Houston Rockets
#     vs Los Angeles Lakers
#     vs Miami Heat
#     vs New York Knicks
#     vs Philadelphia 76ers
#
# (c) Away games vs:
#     Visiting Brooklyn Nets
#     Visiting Chicago Bulls
#     Visiting Cleveland Cavaliers
#     Visiting Dallas Mavericks
#     Visiting Golden State Warriors
#     Visiting Milwaukee Bucks
#     Visiting Phoenix Suns
#     Visiting Toronto Raptors
#
# (d) Away games dates (8 games):
# Fri, Nov 28, 2025: Visiting the Cleveland Cavaliers
# Mon, Dec 01, 2025: Visiting the Toronto Raptors
# Mon, Nov 03, 2025: Visiting the Golden State Warriors
# Sat, Nov 01, 2025: Visiting the Brooklyn Nets
# Sat, Nov 29, 2025: Visiting the Chicago Bulls
# Sun, Nov 23, 2025: Visiting the Phoenix Suns
# Thu, Nov 13, 2025: Visiting the Milwaukee Bucks
# Thu, Nov 27, 2025: Visiting the Dallas Mavericks
# Golden State Warriors
#
# (a) Dates for at Home Games (7 games):
#     Mon, Nov 03, 2025: vs Denver Nuggets
#     Mon, Nov 17, 2025: vs New York Knicks
#     Sat, Nov 15, 2025: vs Philadelphia 76ers
#     Thu, Dec 25, 2025: vs Boston Celtics
#     Thu, Nov 27, 2025: vs Cleveland Cavaliers
#     Tue, Nov 11, 2025: vs Milwaukee Bucks
#     Wed, Nov 05, 2025: vs Houston Rockets
#
# (b) Home games vs:
#     vs Boston Celtics
#     vs Cleveland Cavaliers
#     vs Denver Nuggets
#     vs Houston Rockets
#     vs Milwaukee Bucks
#     vs New York Knicks
#     vs Philadelphia 76ers
#
# (c) Away games vs:
#     Visiting Atlanta Hawks
#     Visiting Boston Celtics
#     Visiting Brooklyn Nets
#     Visiting Chicago Bulls
#     Visiting Dallas Mavericks
#     Visiting Los Angeles Lakers
#     Visiting Miami Heat
#     Visiting Phoenix Suns
#     Visiting Toronto Raptors
#
# (d) Away games dates (9 games):
# Fri, Nov 07, 2025: Visiting the Atlanta Hawks
# Fri, Nov 21, 2025: Visiting the Phoenix Suns
# Fri, Nov 28, 2025: Visiting the Chicago Bulls
# Mon, Dec 01, 2025: Visiting the Brooklyn Nets
# Sat, Nov 01, 2025: Visiting the Boston Celtics
# Sat, Nov 29, 2025: Visiting the Toronto Raptors
# Sun, Nov 23, 2025: Visiting the Dallas Mavericks
# Thu, Nov 13, 2025: Visiting the Miami Heat
# Wed, Nov 19, 2025: Visiting the Los Angeles Lakers
# Houston Rockets
#
# (a) Dates for at Home Games (9 games):
#     Fri, Nov 21, 2025: vs New York Knicks
#     Mon, Nov 03, 2025: vs Brooklyn Nets
#     Sat, Nov 15, 2025: vs Milwaukee Bucks
#     Sun, Nov 23, 2025: vs Los Angeles Lakers
#     Thu, Dec 25, 2025: vs Toronto Raptors
#     Thu, Nov 13, 2025: vs Atlanta Hawks
#     Thu, Nov 27, 2025: vs Phoenix Suns
#     Tue, Nov 11, 2025: vs Boston Celtics
#     Wed, Nov 19, 2025: vs Philadelphia 76ers
#
# (b) Home games vs:
#     vs Atlanta Hawks
#     vs Boston Celtics
#     vs Brooklyn Nets
#     vs Los Angeles Lakers
#     vs Milwaukee Bucks
#     vs New York Knicks
#     vs Philadelphia 76ers
#     vs Phoenix Suns
#     vs Toronto Raptors
#
# (c) Away games vs:
#     Visiting Chicago Bulls
#     Visiting Cleveland Cavaliers
#     Visiting Dallas Mavericks
#     Visiting Denver Nuggets
#     Visiting Golden State Warriors
#     Visiting Miami Heat
#     Visiting Toronto Raptors
#
# (d) Away games dates (7 games):
# Fri, Nov 07, 2025: Visiting the Denver Nuggets
# Fri, Nov 28, 2025: Visiting the Dallas Mavericks
# Mon, Dec 01, 2025: Visiting the Chicago Bulls
# Mon, Nov 17, 2025: Visiting the Miami Heat
# Sat, Nov 01, 2025: Visiting the Toronto Raptors
# Sat, Nov 29, 2025: Visiting the Cleveland Cavaliers
# Wed, Nov 05, 2025: Visiting the Golden State Warriors
# Los Angeles Lakers
#
# (a) Dates for at Home Games (7 games):
#     Mon, Nov 03, 2025: vs Boston Celtics
#     Mon, Nov 17, 2025: vs Brooklyn Nets
#     Sat, Nov 15, 2025: vs Toronto Raptors
#     Thu, Dec 25, 2025: vs New York Knicks
#     Tue, Nov 11, 2025: vs Cleveland Cavaliers
#     Wed, Nov 05, 2025: vs Phoenix Suns
#     Wed, Nov 19, 2025: vs Golden State Warriors
#
# (b) Home games vs:
#     vs Boston Celtics
#     vs Brooklyn Nets
#     vs Cleveland Cavaliers
#     vs Golden State Warriors
#     vs New York Knicks
#     vs Phoenix Suns
#     vs Toronto Raptors
#
# (c) Away games vs:
#     Visiting Atlanta Hawks
#     Visiting Chicago Bulls
#     Visiting Dallas Mavericks
#     Visiting Denver Nuggets
#     Visiting Houston Rockets
#     Visiting Miami Heat
#     Visiting Milwaukee Bucks
#     Visiting New York Knicks
#     Visiting Philadelphia 76ers
#
# (d) Away games dates (9 games):
# Fri, Nov 07, 2025: Visiting the Dallas Mavericks
# Fri, Nov 21, 2025: Visiting the Denver Nuggets
# Fri, Nov 28, 2025: Visiting the Milwaukee Bucks
# Mon, Dec 01, 2025: Visiting the Philadelphia 76ers
# Sat, Nov 01, 2025: Visiting the New York Knicks
# Sat, Nov 29, 2025: Visiting the Miami Heat
# Sun, Nov 23, 2025: Visiting the Houston Rockets
# Thu, Nov 13, 2025: Visiting the Chicago Bulls
# Thu, Nov 27, 2025: Visiting the Atlanta Hawks
# Miami Heat
#
# (a) Dates for at Home Games (8 games):
#     Fri, Nov 28, 2025: vs New York Knicks
#     Mon, Dec 01, 2025: vs Phoenix Suns
#     Mon, Nov 17, 2025: vs Houston Rockets
#     Sat, Nov 01, 2025: vs Dallas Mavericks
#     Sat, Nov 29, 2025: vs Los Angeles Lakers
#     Thu, Nov 13, 2025: vs Golden State Warriors
#     Thu, Nov 27, 2025: vs Philadelphia 76ers
#     Wed, Nov 05, 2025: vs Chicago Bulls
#
# (b) Home games vs:
#     vs Chicago Bulls
#     vs Dallas Mavericks
#     vs Golden State Warriors
#     vs Houston Rockets
#     vs Los Angeles Lakers
#     vs New York Knicks
#     vs Philadelphia 76ers
#     vs Phoenix Suns
#
# (c) Away games vs:
#     Visiting Atlanta Hawks
#     Visiting Boston Celtics
#     Visiting Brooklyn Nets
#     Visiting Cleveland Cavaliers
#     Visiting Dallas Mavericks
#     Visiting Denver Nuggets
#     Visiting Milwaukee Bucks
#     Visiting Toronto Raptors
#
# (d) Away games dates (8 games):
# Fri, Nov 07, 2025: Visiting the Toronto Raptors
# Fri, Nov 21, 2025: Visiting the Milwaukee Bucks
# Mon, Nov 03, 2025: Visiting the Cleveland Cavaliers
# Sat, Nov 15, 2025: Visiting the Denver Nuggets
# Sun, Nov 23, 2025: Visiting the Boston Celtics
# Thu, Dec 25, 2025: Visiting the Dallas Mavericks
# Tue, Nov 11, 2025: Visiting the Brooklyn Nets
# Wed, Nov 19, 2025: Visiting the Atlanta Hawks
# Milwaukee Bucks
#
# (a) Dates for at Home Games (9 games):
#     Fri, Nov 07, 2025: vs Brooklyn Nets
#     Fri, Nov 21, 2025: vs Miami Heat
#     Fri, Nov 28, 2025: vs Los Angeles Lakers
#     Mon, Dec 01, 2025: vs Dallas Mavericks
#     Sat, Nov 01, 2025: vs Cleveland Cavaliers
#     Sat, Nov 29, 2025: vs Phoenix Suns
#     Sun, Nov 23, 2025: vs Philadelphia 76ers
#     Thu, Nov 13, 2025: vs Denver Nuggets
#     Thu, Nov 27, 2025: vs New York Knicks
#
# (b) Home games vs:
#     vs Brooklyn Nets
#     vs Cleveland Cavaliers
#     vs Dallas Mavericks
#     vs Denver Nuggets
#     vs Los Angeles Lakers
#     vs Miami Heat
#     vs New York Knicks
#     vs Philadelphia 76ers
#     vs Phoenix Suns
#
# (c) Away games vs:
#     Visiting Atlanta Hawks
#     Visiting Boston Celtics
#     Visiting Chicago Bulls
#     Visiting Cleveland Cavaliers
#     Visiting Golden State Warriors
#     Visiting Houston Rockets
#     Visiting Toronto Raptors
#
# (d) Away games dates (7 games):
# Mon, Nov 03, 2025: Visiting the Chicago Bulls
# Mon, Nov 17, 2025: Visiting the Atlanta Hawks
# Sat, Nov 15, 2025: Visiting the Houston Rockets
# Thu, Dec 25, 2025: Visiting the Cleveland Cavaliers
# Tue, Nov 11, 2025: Visiting the Golden State Warriors
# Wed, Nov 05, 2025: Visiting the Toronto Raptors
# Wed, Nov 19, 2025: Visiting the Boston Celtics
# New York Knicks
#
# (a) Dates for at Home Games (6 games):
#     Mon, Dec 01, 2025: vs Boston Celtics
#     Sat, Nov 01, 2025: vs Los Angeles Lakers
#     Sat, Nov 15, 2025: vs Brooklyn Nets
#     Thu, Nov 13, 2025: vs Toronto Raptors
#     Tue, Nov 11, 2025: vs Chicago Bulls
#     Wed, Nov 05, 2025: vs Dallas Mavericks
#
# (b) Home games vs:
#     vs Boston Celtics
#     vs Brooklyn Nets
#     vs Chicago Bulls
#     vs Dallas Mavericks
#     vs Los Angeles Lakers
#     vs Toronto Raptors
#
# (c) Away games vs:
#     Visiting Atlanta Hawks
#     Visiting Cleveland Cavaliers
#     Visiting Denver Nuggets
#     Visiting Golden State Warriors
#     Visiting Houston Rockets
#     Visiting Los Angeles Lakers
#     Visiting Miami Heat
#     Visiting Milwaukee Bucks
#     Visiting Philadelphia 76ers
#     Visiting Phoenix Suns
#
# (d) Away games dates (10 games):
# Fri, Nov 07, 2025: Visiting the Cleveland Cavaliers
# Fri, Nov 21, 2025: Visiting the Houston Rockets
# Fri, Nov 28, 2025: Visiting the Miami Heat
# Mon, Nov 03, 2025: Visiting the Phoenix Suns
# Mon, Nov 17, 2025: Visiting the Golden State Warriors
# Sat, Nov 29, 2025: Visiting the Philadelphia 76ers
# Sun, Nov 23, 2025: Visiting the Atlanta Hawks
# Thu, Dec 25, 2025: Visiting the Los Angeles Lakers
# Thu, Nov 27, 2025: Visiting the Milwaukee Bucks
# Wed, Nov 19, 2025: Visiting the Denver Nuggets
# Philadelphia 76ers
#
# (a) Dates for at Home Games (7 games):
#     Fri, Nov 07, 2025: vs Chicago Bulls
#     Fri, Nov 21, 2025: vs Atlanta Hawks
#     Mon, Dec 01, 2025: vs Los Angeles Lakers
#     Sat, Nov 01, 2025: vs Phoenix Suns
#     Sat, Nov 29, 2025: vs New York Knicks
#     Tue, Nov 11, 2025: vs Toronto Raptors
#     Wed, Nov 05, 2025: vs Cleveland Cavaliers
#
# (b) Home games vs:
#     vs Atlanta Hawks
#     vs Chicago Bulls
#     vs Cleveland Cavaliers
#     vs Los Angeles Lakers
#     vs New York Knicks
#     vs Phoenix Suns
#     vs Toronto Raptors
#
# (c) Away games vs:
#     Visiting Boston Celtics
#     Visiting Brooklyn Nets
#     Visiting Dallas Mavericks
#     Visiting Denver Nuggets
#     Visiting Golden State Warriors
#     Visiting Houston Rockets
#     Visiting Miami Heat
#     Visiting Milwaukee Bucks
#     Visiting Phoenix Suns
#
# (d) Away games dates (9 games):
# Fri, Nov 28, 2025: Visiting the Boston Celtics
# Mon, Nov 03, 2025: Visiting the Dallas Mavericks
# Mon, Nov 17, 2025: Visiting the Denver Nuggets
# Sat, Nov 15, 2025: Visiting the Golden State Warriors
# Sun, Nov 23, 2025: Visiting the Milwaukee Bucks
# Thu, Dec 25, 2025: Visiting the Phoenix Suns
# Thu, Nov 13, 2025: Visiting the Brooklyn Nets
# Thu, Nov 27, 2025: Visiting the Miami Heat
# Wed, Nov 19, 2025: Visiting the Houston Rockets
# Phoenix Suns
#
# (a) Dates for at Home Games (8 games):
#     Fri, Nov 21, 2025: vs Golden State Warriors
#     Mon, Nov 03, 2025: vs New York Knicks
#     Sat, Nov 15, 2025: vs Chicago Bulls
#     Sun, Nov 23, 2025: vs Denver Nuggets
#     Thu, Dec 25, 2025: vs Philadelphia 76ers
#     Thu, Nov 13, 2025: vs Cleveland Cavaliers
#     Tue, Nov 11, 2025: vs Dallas Mavericks
#     Wed, Nov 19, 2025: vs Brooklyn Nets
#
# (b) Home games vs:
#     vs Brooklyn Nets
#     vs Chicago Bulls
#     vs Cleveland Cavaliers
#     vs Dallas Mavericks
#     vs Denver Nuggets
#     vs Golden State Warriors
#     vs New York Knicks
#     vs Philadelphia 76ers
#
# (c) Away games vs:
#     Visiting Atlanta Hawks
#     Visiting Boston Celtics
#     Visiting Houston Rockets
#     Visiting Los Angeles Lakers
#     Visiting Miami Heat
#     Visiting Milwaukee Bucks
#     Visiting Philadelphia 76ers
#     Visiting Toronto Raptors
#
# (d) Away games dates (8 games):
# Fri, Nov 07, 2025: Visiting the Boston Celtics
# Fri, Nov 28, 2025: Visiting the Atlanta Hawks
# Mon, Dec 01, 2025: Visiting the Miami Heat
# Mon, Nov 17, 2025: Visiting the Toronto Raptors
# Sat, Nov 01, 2025: Visiting the Philadelphia 76ers
# Sat, Nov 29, 2025: Visiting the Milwaukee Bucks
# Thu, Nov 27, 2025: Visiting the Houston Rockets
# Wed, Nov 05, 2025: Visiting the Los Angeles Lakers
# Toronto Raptors
#
# (a) Dates for at Home Games (8 games):
#     Fri, Nov 07, 2025: vs Miami Heat
#     Fri, Nov 28, 2025: vs Brooklyn Nets
#     Mon, Dec 01, 2025: vs Denver Nuggets
#     Mon, Nov 17, 2025: vs Phoenix Suns
#     Sat, Nov 01, 2025: vs Houston Rockets
#     Sat, Nov 29, 2025: vs Golden State Warriors
#     Thu, Nov 27, 2025: vs Boston Celtics
#     Wed, Nov 05, 2025: vs Milwaukee Bucks
#
# (b) Home games vs:
#     vs Boston Celtics
#     vs Brooklyn Nets
#     vs Denver Nuggets
#     vs Golden State Warriors
#     vs Houston Rockets
#     vs Miami Heat
#     vs Milwaukee Bucks
#     vs Phoenix Suns
#
# (c) Away games vs:
#     Visiting Atlanta Hawks
#     Visiting Chicago Bulls
#     Visiting Cleveland Cavaliers
#     Visiting Dallas Mavericks
#     Visiting Houston Rockets
#     Visiting Los Angeles Lakers
#     Visiting New York Knicks
#     Visiting Philadelphia 76ers
#
# (d) Away games dates (8 games):
# Fri, Nov 21, 2025: Visiting the Cleveland Cavaliers
# Mon, Nov 03, 2025: Visiting the Atlanta Hawks
# Sat, Nov 15, 2025: Visiting the Los Angeles Lakers
# Sun, Nov 23, 2025: Visiting the Chicago Bulls
# Thu, Dec 25, 2025: Visiting the Houston Rockets
# Thu, Nov 13, 2025: Visiting the New York Knicks
# Tue, Nov 11, 2025: Visiting the Philadelphia 76ers
# Wed, Nov 19, 2025: Visiting the Dallas Mavericks

# %% [markdown]
# ---------------

# %% [markdown]
# ## 2. Write an Integer Program (without objective function) whose feasible solutions are all the feasible schedules, where a schedule is feasible if, for each team i:

# %% [markdown]
# (e) i plays home (possibly, against a different team) exactly on the dates computed
# in (a) above;
#
# (f) plays away (possibly, against a different team) exactly on the dates computed in
# (d) above;
#
# (g) for each team j, i plays home against team j exactly the number of times computed
# in (b) above;
#
# (h) for each team j, i plays away against team j (i.e., at j’s home) exactly the number
# of times computed in (c) above.

# %% [markdown]
# **Sets**
# - Teams: $T$ = Teams in the league (16 teams)
# - Fixture Dates : $F$ = Fixture dates in the schedule (16 dates)
#
# **Parameters**
#
# - $\text{Home}_i$: dates when team $i$ plays at home, for each team $i \in T$
# - $\text{Away}_i$: dates when team $i$ plays away, for each team $i \in T$
#
# - $l_{ij}$: number of times team $i$ plays against team $j$ at home, $\forall$ team $i \in T$
# - $v_{ij}$: number of times team $i$ plays at team $j$'s stadium, $\forall$ team $i \in T$
#
# **Decision Variables**
#
# $$x_{ijf} = \begin{cases} 1 & \text{if team } i \text{ hosts team } j \text{ on date } f \\ 0 & \text{otherwise} \end{cases}$$
#
# $\forall i,j \in T, i \neq j, \forall f \in F$

# %% [markdown]
# (e) Games at home date constraint
#
# For each team $i \in T$ and each fixture date $f \in F$:
#
# $$\sum_{\substack{j \in T \\ j \neq i}} x_{ijf} = \begin{cases} 1 & \text{if } f \in \text{Home}_i \\ 0 & \text{otherwise} \end{cases}$$
#
# Team $i$ plays exactly one home game on date $f$, if $f$ is one of their designated home dates, and plays no home games on date $f$ otherwise.

# %% [markdown]
# (f) Away Dates from calculation from 1.d.
#
# For each team $i \in T$ and each fixture date $f \in F$:
#
# $$\sum_{\substack{j \in T \\ j \neq i}} x_{jif} = \begin{cases} 1 & \text{if } f \in \text{Away}_i \\ 0 & \text{otherwise} \end{cases}$$
#
# This is so that team $i$ plays  one away game on date $f$ if $f$ is one of their selected away dates from the data.

# %% [markdown]
# (g) Home Matches counted in 1.b.
#
# For all team fixtures $(i, j) \in T$ where $i \neq j$:
#
# $$\sum_{f \in F} x_{ijf} = l_{ij}$$
#
# This constraint ensures that team $i$ hosts team $j$  $l_{ij}$ times across all fixture dates, matching the original schedule.

# %% [markdown]
# (h) Away Matches countes in 1.c.
#
# For all matchups $(i, j) \in T$,  $i \neq j$:
#
# $$\sum_{f \in F} x_{jif} = v_{ij}$$
#
# This ensures that team $i$ visits team $j$'s arena exactly $v_{ij}$ times.

# %%
### Define Sets
T = sorted(set(nba_sc["Home"].unique()).union(set(nba_sc["Visitor"].unique())))  
F = sorted(nba_sc["Date"].unique())  
 
print(f"Set T (Teams): {len(T)} teams")
print(f"Set F (Fixture Dates): {len(F)} dates")
 
### Compute Params. for each team
Home = {}  
Away = {}  
l = {}     # l_ij
v = {}     # v_ij
 
for i in T:
    #Get all games where team i is home or away
    home_games = nba_sc[nba_sc["Home"] == i]
    away_games = nba_sc[nba_sc["Visitor"] == i]
    
    #Extract home and away dates
    Home[i] = sorted(home_games["Date"].unique())
    Away[i] = sorted(away_games["Date"].unique())
    
    #Count matchups
    for j in T:
        if i != j:
            l[i, j] = len(home_games[home_games["Visitor"] == j])
            v[i, j] = len(away_games[away_games["Home"] == j])
# Out:
# Set T (Teams): 16 teams
# Set F (Fixture Dates): 16 dates

# %%
atl_haws = "Atlanta Hawks"
print(f"  Home_{{ATL}} = {len(Home[atl_haws])} dates")
print(f"  Away_{{ATL}} = {len(Away[atl_haws])} dates")
print(f"  Plays Boston at home: l_{{ATL,BOS}} = {l[atl_haws, 'Boston Celtics']} game")
print(f"  Plays at Brooklyn: v_{{ATL,BKN}} = {v[atl_haws, 'Brooklyn Nets']} game")
# Out:
#   Home_{ATL} = 10 dates
#   Away_{ATL} = 6 dates
#   Plays Boston at home: l_{ATL,BOS} = 1 game
#   Plays at Brooklyn: v_{ATL,BKN} = 1 game

# %% [markdown]
# Solving the model formulated for question 2

# %%
# First, compute the sets and parameters from Problem 1
T = sorted(set(nba_sc["Home"].unique()).union(set(nba_sc["Visitor"].unique())))
F = sorted(nba_sc["Date"].unique())

#Build parameter dictionaries
Home = {}
Away = {}
l = {}
v = {}

for i in T:
    home_games = nba_sc[nba_sc["Home"] == i]
    away_games = nba_sc[nba_sc["Visitor"] == i]
    
    Home[i] = sorted(home_games["Date"].unique())
    Away[i] = sorted(away_games["Date"].unique())
    
    for j in T:
        if i != j:
            l[i, j] = len(home_games[home_games["Visitor"] == j])
            v[i, j] = len(away_games[away_games["Home"] == j])

print(f"Sets: {len(T)} teams, {len(F)} fixture dates")
print(f"Parameters computed: Home_i, Away_i, l_ij, v_ij")


model = gp.Model("NBA_Schedule_P2_Q2")
model.setParam("OutputFlag", 0) 

# Decision variables: x[i,j,f] = 1 if team i hosts team j on date f
x = {}
for i in T:
    for j in T:
        if i != j:
            for f in F:
                x[i, j, f] = model.addVar(vtype=GRB.BINARY, name=f"x_{i}_{j}_{f}")

print(f"Variables: {len(x)} binary variables created")

# Constraint e): Home date requirements
for i in T:
    for f in F:
        if f in Home[i]:
            # Team i must play at home on date f
            model.addConstr(gp.quicksum(x[i, j, f] for j in T if j != i) == 1, 
                          name=f"home_{i}_{f}")
        else:
            # Team i cannot play at home on date f
            model.addConstr(gp.quicksum(x[i, j, f] for j in T if j != i) == 0, name=f"no_home_{i}_{f}")

# Constraint f): Away date requirements
for i in T:
    for f in F:
        if f in Away[i]:
            # Team i must play away on date f
            model.addConstr(gp.quicksum(x[j, i, f] for j in T if j != i) == 1, name=f"away_{i}_{f}")
        else:
            # Team i cannot play away on date f
            model.addConstr(gp.quicksum(x[j, i, f] for j in T if j != i) == 0, name=f"no_away_{i}_{f}")

# Constraint (g): Home matchup counts
for i in T:
    for j in T:
        if i != j:
            model.addConstr(gp.quicksum(x[i, j, f] for f in F) == l[i, j], name=f"home_match_{i}_{j}")

# Constraint (h): Away matchup counts
for i in T:
    for j in T:
        if i != j:
            model.addConstr(gp.quicksum(x[j, i, f] for f in F) == v[i, j], name=f"away_match_{i}_{j}")

model.optimize()


if model.status == GRB.OPTIMAL:
    print("Feasible solution found for problem 2")
    
    # Extract the schedule
    schedule = []
    for i in T:
        for j in T:
            if i != j:
                for f in F:
                    if x[i, j, f].X > 0.5:  # Variable is 1
                        schedule.append({"Date": f, "Home": i, "Away": j})
    
    schedule_df = pd.DataFrame(schedule)
    schedule_df = schedule_df.sort_values(["Date", "Home"])
    
    print(f"Generated schedule: {len(schedule_df)} games")
    print("\nFirst 10 games:")
    print(schedule_df.head(10).to_string(index=False))
    
else:
    print("No feasible solution found")
# Out:
# Sets: 16 teams, 16 fixture dates
# Parameters computed: Home_i, Away_i, l_ij, v_ij
# Variables: 3840 binary variables created
# Feasible solution found for problem 2
# Generated schedule: 128 games
#
# First 10 games:
#              Date                Home                  Away
# Fri, Nov 07, 2025       Atlanta Hawks          Phoenix Suns
# Fri, Nov 07, 2025      Boston Celtics Golden State Warriors
# Fri, Nov 07, 2025 Cleveland Cavaliers         Chicago Bulls
# Fri, Nov 07, 2025    Dallas Mavericks       Houston Rockets
# Fri, Nov 07, 2025      Denver Nuggets    Los Angeles Lakers
# Fri, Nov 07, 2025     Milwaukee Bucks         Brooklyn Nets
# Fri, Nov 07, 2025  Philadelphia 76ers       New York Knicks
# Fri, Nov 07, 2025     Toronto Raptors            Miami Heat
# Fri, Nov 21, 2025       Brooklyn Nets      Dallas Mavericks
# Fri, Nov 21, 2025       Chicago Bulls Golden State Warriors

# %% [markdown]
# ---------------------

# %% [markdown]
# ## 3. Compute a feasible schedule that satisfy the following additional constraint: no team should play three consecutive matches where the sum of the absolute values of the difference between the time zones of two consecutive matches is 4 or more; or conclude that no such schedule exists.

# %%
tz = {"Atlanta Hawks": 0, "Boston Celtics": 0, "Brooklyn Nets": 0,"Cleveland Cavaliers": 0, "Miami Heat": 0, "New York Knicks": 0, "Philadelphia 76ers": 0, "Toronto Raptors": 0, 
     "Chicago Bulls": 1, "Dallas Mavericks": 1,"Houston Rockets": 1, "Milwaukee Bucks": 1,"Denver Nuggets": 2, "Phoenix Suns": 2,"Golden State Warriors": 3, "Los Angeles Lakers": 3}
def get_tz_expr(i, f):
    if f in Home[i]:
        return tz[i]  ## playing at home, tz is a constant
    else:
        # playing away: tz = sum over opponents j of tz[j] *x[j,i,f]
        return gp.quicksum(tz[j] * x[j, i, f] for j in T if j != i)

# %%
F_s = sorted(F, key=lambda d: pd.to_datetime(d, format="%a, %b %d, %Y"))

# %%
model = gp.Model("NBA_Schedule_P2_Q3")
model.setParam("OutputFlag", 1) 
# Decision variables: x[i,j,f] = 1 if team i hosts team j on date f
x = {}
for i in T:
    for j in T:
        if i != j:
            for f in F:
                x[i, j, f] = model.addVar(vtype=GRB.BINARY, name=f"x_{i}_{j}_{f}")
# Constraint e): Home date requirements
for i in T:
    for f in F:
        if f in Home[i]:
            # Team i must play at home on date f
            model.addConstr(gp.quicksum(x[i, j, f] for j in T if j != i) == 1, 
                          name=f"home_{i}_{f}")
        else:
            # Team i cannot play at home on date f
            model.addConstr(gp.quicksum(x[i, j, f] for j in T if j != i) == 0,name=f"no_home_{i}_{f}")
# Constraint f): Away date requirements
for i in T:
    for f in F:
        if f in Away[i]:
            # Team i must play away on date f
            model.addConstr(gp.quicksum(x[j, i, f] for j in T if j != i) == 1,name=f"away_{i}_{f}")
        else:
            # Team i cannot play away on date f
            model.addConstr(gp.quicksum(x[j, i, f] for j in T if j != i) == 0,name=f"no_away_{i}_{f}")
# Constraint (g): Home matchup counts
for i in T:
    for j in T:
        if i != j:
            model.addConstr(gp.quicksum(x[i, j, f] for f in F) == l[i, j], name=f"home_match_{i}_{j}")
# Constraint (h): Away matchup counts
for i in T:
    for j in T:
        if i != j:
            model.addConstr(gp.quicksum(x[j, i, f] for f in F) == v[i, j], name=f"away_match_{i}_{j}")

""" 
New constraints (Q3)
"""
#For each team i look at the next three games 
for i in T:
    for k in range(len(F_s)-2):
        f1, f2, f3 = F_s[k], F_s[k+1], F_s[k+2]
        timezone1 = get_tz_expr(i, f1)
        timezone2 = get_tz_expr(i, f2)
        timezone3 = get_tz_expr(i, f3)
        
        # Auxiliary variables for |timezone1 - timezone2| and |timezone2 - timezone3|
        d1 = model.addVar(lb=0, name=f"d_{i}_{k}_1")
        d2 = model.addVar(lb=0, name=f"d_{i}_{k}_2")
        # Linearize |timezone1 - timezone2|: d1 >= timezone1 - timezone2 and d1 >= timezone2 - timezone1
        model.addConstr(d1 >= timezone1 - timezone2, name=f"abs1a_{i}_{k}")
        model.addConstr(d1 >= timezone2 - timezone1, name=f"abs1b_{i}_{k}")
        # Linearize |timezone2 - timezone3|: d2 >= timezone2 - timezone3 and d2 >= timezone3 - timezone2
        model.addConstr(d2 >= timezone2 - timezone3, name=f"abs2a_{i}_{k}")
        model.addConstr(d2 >= timezone3 - timezone2, name=f"abs2b_{i}_{k}")
        
        #sum of consecutive timezone jumps must be < 4
        model.addConstr(d1 + d2 <= 3, name=f"tz_limit_{i}_{k}")
 
model.optimize()
# Out:
# Set parameter OutputFlag to value 1
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Optimize a model with 2112 rows, 4288 columns and 23440 nonzeros (Min)
# Model fingerprint: 0x25c9c4c5
# Model has 0 linear objective coefficients
# Variable types: 448 continuous, 3840 integer (3840 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+00]
#   Objective range  [0e+00, 0e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 3e+00]
#
# Presolve removed 350 rows and 0 columns
# Presolve time: 0.00s
#
# Explored 0 nodes (0 simplex iterations) in 0.04 seconds (0.00 work units)
# Thread count was 1 (of 8 available processors)
#
# Solution count 0
#
# Model is infeasible
# Best objective -, best bound -, gap -

# %%
if model.status == GRB.OPTIMAL:
    print("Feasible solution found!")
else:
    print("No feasible solution found")
# Out:
# No feasible solution found

# %%
conflicts = 0
teams_conflicted = set()
for team in T:
    game_tzs = []
    for f in F_s:
        home_game = nba_sc[(nba_sc["Home"] == team) & (nba_sc["Date"] == f)]
        away_game = nba_sc[(nba_sc["Visitor"] == team) & (nba_sc["Date"] == f)]
        
        if len(home_game) > 0:
            game_tzs.append((f, tz[team], "home"))
        elif len(away_game) > 0:
            opponent = away_game["Home"].values[0]
            game_tzs.append((f, tz[opponent], f"visiting the {opponent}"))

    for k in range(len(game_tzs) - 2):
        f1, tz1, loc1 = game_tzs[k]
        f2, tz2, loc2 = game_tzs[k + 1]
        f3, tz3, loc3 = game_tzs[k + 2]
        
        diff_sum = abs(tz1 - tz2) + abs(tz2 - tz3)
        
        if diff_sum >= 4:
            conflicts += 1
            teams_conflicted.add(team)
            print(f"CONFLICT: {team}")
            print(f"  Game {k+1}: {f1} (tz={tz1}, {loc1})")
            print(f"  Game {k+2}: {f2} (tz={tz2}, {loc2})")
            print(f"  Game {k+3}: {f3} (tz={tz3}, {loc3})")
            print(f"{abs(tz1-tz2)} + {abs(tz2-tz3)} = {diff_sum} >= 4\n")

print(f"Total conflicts in original schedule: {conflicts}")
print(f"Teams affected: {len(teams_conflicted)}")
# Out:
# CONFLICT: Boston Celtics
#   Game 1: Sat, Nov 01, 2025 (tz=0, home)
#   Game 2: Mon, Nov 03, 2025 (tz=3, visiting the Los Angeles Lakers)
#   Game 3: Wed, Nov 05, 2025 (tz=2, visiting the Denver Nuggets)
# 3 + 1 = 4 >= 4
#
# CONFLICT: Brooklyn Nets
#   Game 7: Sat, Nov 15, 2025 (tz=0, visiting the New York Knicks)
#   Game 8: Mon, Nov 17, 2025 (tz=3, visiting the Los Angeles Lakers)
#   Game 9: Wed, Nov 19, 2025 (tz=2, visiting the Phoenix Suns)
# 3 + 1 = 4 >= 4
#
# CONFLICT: Cleveland Cavaliers
#   Game 4: Fri, Nov 07, 2025 (tz=0, home)
#   Game 5: Tue, Nov 11, 2025 (tz=3, visiting the Los Angeles Lakers)
#   Game 6: Thu, Nov 13, 2025 (tz=2, visiting the Phoenix Suns)
# 3 + 1 = 4 >= 4
#
# CONFLICT: Cleveland Cavaliers
#   Game 11: Sun, Nov 23, 2025 (tz=0, home)
#   Game 12: Thu, Nov 27, 2025 (tz=3, visiting the Golden State Warriors)
#   Game 13: Fri, Nov 28, 2025 (tz=0, home)
# 3 + 3 = 6 >= 4
#
# CONFLICT: Denver Nuggets
#   Game 1: Sat, Nov 01, 2025 (tz=0, visiting the Brooklyn Nets)
#   Game 2: Mon, Nov 03, 2025 (tz=3, visiting the Golden State Warriors)
#   Game 3: Wed, Nov 05, 2025 (tz=2, home)
# 3 + 1 = 4 >= 4
#
# CONFLICT: Golden State Warriors
#   Game 3: Wed, Nov 05, 2025 (tz=3, home)
#   Game 4: Fri, Nov 07, 2025 (tz=0, visiting the Atlanta Hawks)
#   Game 5: Tue, Nov 11, 2025 (tz=3, home)
# 3 + 3 = 6 >= 4
#
# CONFLICT: Golden State Warriors
#   Game 4: Fri, Nov 07, 2025 (tz=0, visiting the Atlanta Hawks)
#   Game 5: Tue, Nov 11, 2025 (tz=3, home)
#   Game 6: Thu, Nov 13, 2025 (tz=0, visiting the Miami Heat)
# 3 + 3 = 6 >= 4
#
# CONFLICT: Golden State Warriors
#   Game 5: Tue, Nov 11, 2025 (tz=3, home)
#   Game 6: Thu, Nov 13, 2025 (tz=0, visiting the Miami Heat)
#   Game 7: Sat, Nov 15, 2025 (tz=3, home)
# 3 + 3 = 6 >= 4
#
# CONFLICT: Golden State Warriors
#   Game 11: Sun, Nov 23, 2025 (tz=1, visiting the Dallas Mavericks)
#   Game 12: Thu, Nov 27, 2025 (tz=3, home)
#   Game 13: Fri, Nov 28, 2025 (tz=1, visiting the Chicago Bulls)
# 2 + 2 = 4 >= 4
#
# CONFLICT: Los Angeles Lakers
#   Game 3: Wed, Nov 05, 2025 (tz=3, home)
#   Game 4: Fri, Nov 07, 2025 (tz=1, visiting the Dallas Mavericks)
#   Game 5: Tue, Nov 11, 2025 (tz=3, home)
# 2 + 2 = 4 >= 4
#
# CONFLICT: Los Angeles Lakers
#   Game 4: Fri, Nov 07, 2025 (tz=1, visiting the Dallas Mavericks)
#   Game 5: Tue, Nov 11, 2025 (tz=3, home)
#   Game 6: Thu, Nov 13, 2025 (tz=1, visiting the Chicago Bulls)
# 2 + 2 = 4 >= 4
#
# CONFLICT: Los Angeles Lakers
#   Game 5: Tue, Nov 11, 2025 (tz=3, home)
#   Game 6: Thu, Nov 13, 2025 (tz=1, visiting the Chicago Bulls)
#   Game 7: Sat, Nov 15, 2025 (tz=3, home)
# 2 + 2 = 4 >= 4
#
# CONFLICT: Miami Heat
#   Game 6: Thu, Nov 13, 2025 (tz=0, home)
#   Game 7: Sat, Nov 15, 2025 (tz=2, visiting the Denver Nuggets)
#   Game 8: Mon, Nov 17, 2025 (tz=0, home)
# 2 + 2 = 4 >= 4
#
# CONFLICT: Milwaukee Bucks
#   Game 4: Fri, Nov 07, 2025 (tz=1, home)
#   Game 5: Tue, Nov 11, 2025 (tz=3, visiting the Golden State Warriors)
#   Game 6: Thu, Nov 13, 2025 (tz=1, home)
# 2 + 2 = 4 >= 4
#
# CONFLICT: New York Knicks
#   Game 1: Sat, Nov 01, 2025 (tz=0, home)
#   Game 2: Mon, Nov 03, 2025 (tz=2, visiting the Phoenix Suns)
#   Game 3: Wed, Nov 05, 2025 (tz=0, home)
# 2 + 2 = 4 >= 4
#
# CONFLICT: New York Knicks
#   Game 7: Sat, Nov 15, 2025 (tz=0, home)
#   Game 8: Mon, Nov 17, 2025 (tz=3, visiting the Golden State Warriors)
#   Game 9: Wed, Nov 19, 2025 (tz=2, visiting the Denver Nuggets)
# 3 + 1 = 4 >= 4
#
# CONFLICT: Philadelphia 76ers
#   Game 6: Thu, Nov 13, 2025 (tz=0, visiting the Brooklyn Nets)
#   Game 7: Sat, Nov 15, 2025 (tz=3, visiting the Golden State Warriors)
#   Game 8: Mon, Nov 17, 2025 (tz=2, visiting the Denver Nuggets)
# 3 + 1 = 4 >= 4
#
# CONFLICT: Phoenix Suns
#   Game 2: Mon, Nov 03, 2025 (tz=2, home)
#   Game 3: Wed, Nov 05, 2025 (tz=3, visiting the Los Angeles Lakers)
#   Game 4: Fri, Nov 07, 2025 (tz=0, visiting the Boston Celtics)
# 1 + 3 = 4 >= 4
#
# CONFLICT: Phoenix Suns
#   Game 3: Wed, Nov 05, 2025 (tz=3, visiting the Los Angeles Lakers)
#   Game 4: Fri, Nov 07, 2025 (tz=0, visiting the Boston Celtics)
#   Game 5: Tue, Nov 11, 2025 (tz=2, home)
# 3 + 2 = 5 >= 4
#
# CONFLICT: Phoenix Suns
#   Game 7: Sat, Nov 15, 2025 (tz=2, home)
#   Game 8: Mon, Nov 17, 2025 (tz=0, visiting the Toronto Raptors)
#   Game 9: Wed, Nov 19, 2025 (tz=2, home)
# 2 + 2 = 4 >= 4
#
# CONFLICT: Toronto Raptors
#   Game 6: Thu, Nov 13, 2025 (tz=0, visiting the New York Knicks)
#   Game 7: Sat, Nov 15, 2025 (tz=3, visiting the Los Angeles Lakers)
#   Game 8: Mon, Nov 17, 2025 (tz=0, home)
# 3 + 3 = 6 >= 4
#
# CONFLICT: Toronto Raptors
#   Game 7: Sat, Nov 15, 2025 (tz=3, visiting the Los Angeles Lakers)
#   Game 8: Mon, Nov 17, 2025 (tz=0, home)
#   Game 9: Wed, Nov 19, 2025 (tz=1, visiting the Dallas Mavericks)
# 3 + 1 = 4 >= 4
#
# Total conflicts in original schedule: 22
# Teams affected: 12

# %% [markdown]
# ### We formulated Question 3 by preserving all prior scheduling constraints and adding the requirement that for any team, the sum of timezone jumps across any three consecutive matches must be less than 4. Gurobi returned an infeasible status. Then, the group analyzed the possible schedule and found out that teams with home stadiums in Eastern/Pacific time zones that alternate home-away-home have to go from one side to the other therefore making the problem infeasible

# %% [markdown]
# -------------

# %% [markdown]
# ## 4. Compute any improvement to the current schedule. For instance, using Google Maps, you could compute and store the locations of all arenas, compute a feasible schedule that minimizes the maximum distance traveled by a team, and compare this value with the one of the current schedule to show the improvement.

# %% [markdown]
# ## Data and Arena Coordinates
#
# Arena latitude/longitude values are based on publicly available information for each NBA venue.

# %%
nba_sc = pd.read_csv("games.csv")
nba_sc["Date"] = pd.to_datetime(nba_sc["Date"])

arena_coords = {
    "Atlanta Hawks":         (33.7573,  -84.3963),   # State Farm Arena
    "Boston Celtics":        (42.3662,  -71.0621),   # TD Garden
    "Brooklyn Nets":         (40.6826,  -73.9754),   # Barclays Center
    "Chicago Bulls":         (41.8807,  -87.6742),   # United Center
    "Cleveland Cavaliers":   (41.4965,  -81.6882),   # Rocket Mortgage FieldHouse
    "Dallas Mavericks":      (32.7905,  -96.8103),   # American Airlines Center
    "Denver Nuggets":        (39.7487, -105.0077),   # Ball Arena
    "Golden State Warriors": (37.7680, -122.3877),   # Chase Center
    "Houston Rockets":       (29.7508,  -95.3621),   # Toyota Center
    "Los Angeles Lakers":    (34.0430, -118.2673),   # Crypto.com Arena
    "Miami Heat":            (25.7814,  -80.1870),   # Kaseya Center
    "Milwaukee Bucks":       (43.0451,  -87.9173),   # Fiserv Forum
    "New York Knicks":       (40.7505,  -73.9934),   # Madison Square Garden
    "Philadelphia 76ers":    (39.9012,  -75.1720),   # Wells Fargo Center
    "Phoenix Suns":          (33.4457, -112.0712),   # Footprint Center
    "Toronto Raptors":       (43.6435,  -79.3791),   # Scotiabank Arena
}

# %% [markdown]
# ## Distance Matrix
#
# We use the haversine formula to compute great-circle distances in miles between arenas.

# %%
def haversine(lat1, lon1, lat2, lon2):
    R = 3958.8  # Earth's radius in miles
    phi1, phi2 = math.radians(lat1), math.radians(lat2)
    dphi = math.radians(lat2 - lat1)
    dlam = math.radians(lon2 - lon1)
    a = math.sin(dphi/2)**2 + math.cos(phi1)*math.cos(phi2)*math.sin(dlam/2)**2
    return 2 * R * math.asin(math.sqrt(a))

T = sorted(arena_coords.keys())
F = sorted(nba_sc["Date"].unique())

d = {}
for a in T:
    for b in T:
        la1, lo1 = arena_coords[a]
        la2, lo2 = arena_coords[b]
        d[a, b] = haversine(la1, lo1, la2, lo2)

print(f"Teams: {len(T)}, Dates: {len(F)}")
print(f"Distance range: {min(v for v in d.values() if v > 0):.0f} – {max(d.values()):.0f} miles")
# Out:
# Teams: 16, Dates: 16
# Distance range: 5 – 2691 miles

# %%
home_on = {f: set(nba_sc.loc[nba_sc["Date"] == f, "Home"]) for f in F}
away_on = {f: set(nba_sc.loc[nba_sc["Date"] == f, "Visitor"]) for f in F}

played_dates = {t: sorted(nba_sc.loc[(nba_sc["Home"] == t) | (nba_sc["Visitor"] == t), "Date"].unique()) for t in T}
req_pair = nba_sc.groupby(["Home", "Visitor"]).size().to_dict()

# %% [markdown]
# ## Baseline: Travel in the Original Schedule
#
# Each team's travel is computed as the sum of distances across their full arena sequence: home → first game arena → next game arena → … → last game arena → home.

# %%
schedule_df.head(4)
# Out:
#                  Date                 Home                   Away
# 8   Fri, Nov 07, 2025        Atlanta Hawks           Phoenix Suns
# 11  Fri, Nov 07, 2025       Boston Celtics  Golden State Warriors
# 35  Fri, Nov 07, 2025  Cleveland Cavaliers          Chicago Bulls
# 46  Fri, Nov 07, 2025     Dallas Mavericks        Houston Rockets

# %%
def compute_travel(schedule_df, team):
    games = schedule_df[(schedule_df["Home"] == team) | (schedule_df["Visitor"] == team)].sort_values("Date")
    arenas = [team] + list(games["Home"]) + [team]
    return sum(d[arenas[k], arenas[k+1]] for k in range(len(arenas) - 1))

orig_travel = {t: compute_travel(nba_sc, t) for t in T}

print("Original schedule travel (miles):")
for t in sorted(orig_travel, key=orig_travel.get, reverse=True):
    print(f"  {t:25s}: {orig_travel[t]:7.0f}")

orig_max = max(orig_travel.values())
orig_total = sum(orig_travel.values())
print(f"\nMax travel (worst team):  {orig_max:7.0f} miles")
print(f"Total league travel:      {orig_total:7.0f} miles")
# Out:
# Original schedule travel (miles):
#   Golden State Warriors    :   23091
#   Phoenix Suns             :   18807
#   Los Angeles Lakers       :   18613
#   Boston Celtics           :   18448
#   New York Knicks          :   18116
#   Philadelphia 76ers       :   16055
#   Dallas Mavericks         :   14684
#   Brooklyn Nets            :   14015
#   Miami Heat               :   13908
#   Toronto Raptors          :   12090
#   Denver Nuggets           :   11552
#   Houston Rockets          :   10505
#   Cleveland Cavaliers      :   10024
#   Milwaukee Bucks          :    8794
#   Atlanta Hawks            :    7897
#   Chicago Bulls            :    7854
#
# Max travel (worst team):    23091 miles
# Total league travel:       224453 miles

# %% [markdown]
# ## Model
#
# **Decision variables:**
# - $x_{ijf} \in \{0,1\}$: 1 if team $i$ hosts team $j$ on date $f$ (sparse on original slots)
# - $a_{itf} \in \{0,1\}$: 1 if team $i$ plays at team $t$'s arena on date $f$
# - $z_{i,t_1,t_2,k} \in [0,1]$: 1 if on leg $k$, team $i$ travels from $t_1$'s arena to $t_2$'s arena
# - $D \geq 0$: maximum travel distance across all teams
#
# **Constraints:**
# - (Q2 feasibility) — same as Q3: home slot, away slot, and pair-count constraints
# - **Arena linkage:** exactly one arena per team per played date; if $i$ is home on $f$, arena = $i$; if $i$ is away on $f$, arena follows $x$
# - **Leg linearization:** $z_{i,t_1,t_2,k} \leq a_{i,t_1,f_{k-1}}$, $z_{i,t_1,t_2,k} \leq a_{i,t_2,f_k}$, and $\sum_{t_1,t_2} z = 1$ per leg
# - **Minimax:** $D \geq \text{total travel of team } i$ for every team $i$
#
# **Objective:** $\min D$

# %%
model = gp.Model("Q4_minimax_travel")
model.setParam("OutputFlag", 1)
model.setParam("TimeLimit", 600)

# x: hosting assignment (sparse)
x = {}
for f in F:
    for i in home_on[f]:
        for j in away_on[f]:
            if i != j:
                x[i, j, f] = model.addVar(vtype=GRB.BINARY,
                                          name=f"x_{i}_{j}_{f.strftime('%Y%m%d')}")

# a: arena indicator
a = {}
for i in T:
    for f in played_dates[i]:
        for t in T:
            a[i, t, f] = model.addVar(vtype=GRB.BINARY,
                                      name=f"a_{i}_{t}_{f.strftime('%Y%m%d')}")

# z: transition indicator per leg
z = {}
for i in T:
    P = played_dates[i]
    for k in range(1, len(P)):
        for t1 in T:
            for t2 in T:
                z[i, t1, t2, k] = model.addVar(lb=0, ub=1, vtype=GRB.CONTINUOUS,
                                               name=f"z_{i}_{t1}_{t2}_{k}")

# D: max travel
D = model.addVar(lb=0, vtype=GRB.CONTINUOUS, name="D")

model.update()
print(f"Variables: {model.NumVars}")

# Q2 feasibility constraints
for f in F:
    for i in home_on[f]:
        model.addConstr(gp.quicksum(x[i, j, f] for j in away_on[f] if i != j) == 1)
    for j in away_on[f]:
        model.addConstr(gp.quicksum(x[i, j, f] for i in home_on[f] if i != j) == 1)

for i in T:
    for j in T:
        if i != j:
            rhs = req_pair.get((i, j), 0)
            model.addConstr(gp.quicksum(x[i, j, f] for f in F if (i, j, f) in x) == rhs)

# Arena linkage
for i in T:
    for f in played_dates[i]:
        model.addConstr(gp.quicksum(a[i, t, f] for t in T) == 1)
        if i in home_on[f]:
            model.addConstr(a[i, i, f] == 1)
        else:
            for t in T:
                if t in home_on[f] and (t, i, f) in x:
                    model.addConstr(a[i, t, f] == x[t, i, f])
                else:
                    model.addConstr(a[i, t, f] == 0)

# Leg linearization: z captures the (t1, t2) transition on leg k
for i in T:
    P = played_dates[i]
    for k in range(1, len(P)):
        f1, f2 = P[k-1], P[k]
        for t1 in T:
            for t2 in T:
                model.addConstr(z[i, t1, t2, k] <= a[i, t1, f1])
                model.addConstr(z[i, t1, t2, k] <= a[i, t2, f2])
        model.addConstr(gp.quicksum(z[i, t1, t2, k] for t1 in T for t2 in T) == 1)

# Team travel = pre-season leg + between-game legs + post-season leg
team_travel = {}
for i in T:
    P = played_dates[i]
    expr = gp.quicksum(d[i, t] * a[i, t, P[0]] for t in T)
    for k in range(1, len(P)):
        expr += gp.quicksum(d[t1, t2] * z[i, t1, t2, k] for t1 in T for t2 in T)
    expr += gp.quicksum(d[t, i] * a[i, t, P[-1]] for t in T)
    team_travel[i] = expr
    model.addConstr(D >= expr)

model.setObjective(D, GRB.MINIMIZE)
model.optimize()
# Out:
# Set parameter OutputFlag to value 1
# Set parameter TimeLimit to value 600
# Variables: 66561
# Constraints: 0
#
# Optimizing...
# Gurobi Optimizer version 13.0.1 build v13.0.1rc0 (win64 - Windows 11+.0 (26200.2))
#
# CPU model: Intel(R) Core(TM) i7-8565U CPU @ 1.80GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
#
# Non-default parameters:
# TimeLimit  600
#
# Optimize a model with 126064 rows, 66561 columns and 375664 nonzeros (Min)
# Model fingerprint: 0x5577a2cc
# Model has 1 linear objective coefficients
# Variable types: 61441 continuous, 5120 integer (5120 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+03]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
#
# Presolve removed 123247 rows and 64766 columns
# Presolve time: 0.28s
# Presolved: 2817 rows, 1795 columns, 8913 nonzeros
# Variable types: 1332 continuous, 463 integer (463 binary)
# Found heuristic solution: objective 23596.931625
# Performing another presolve...
# Presolve removed 1071 rows and 661 columns
# Presolve time: 0.15s
#
# Root relaxation: objective 2.037354e+04, 1193 iterations, 0.13 seconds (0.05 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 20373.5440    0  210 23596.9316 20373.5440  13.7%     -    1s
# H    0     0                    23199.728697 20373.5440  12.2%     -    1s
# H    0     0                    21131.904207 20373.5440  3.59%     -    1s
# H    0     0                    20736.183941 20373.5440  1.75%     -    1s
#
# Cutting planes:
#   Gomory: 17
#   MIR: 2
#   Zero half: 23
#   RLT: 53
#   Relax-and-lift: 10
#   BQP: 41
#
# Explored 1 nodes (1715 simplex iterations) in 1.27 seconds (0.28 work units)
# Thread count was 8 (of 8 available processors)
#
# Solution count 4: 20736.2 21131.9 23199.7 23596.9
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 2.073618394084e+04, best bound 2.073618394084e+04, gap 0.0000%

# %%
if model.status in (GRB.OPTIMAL, GRB.TIME_LIMIT) and model.SolCount > 0:
    opt_max = D.X
    opt_travel = {i: team_travel[i].getValue() for i in T}
    opt_total = sum(opt_travel.values())

    print(f"Optimized max travel: {opt_max:.0f} miles")
    print(f"Optimized total:      {opt_total:.0f} miles\n")

    comparison = pd.DataFrame({
        "Team": T,
        "Original": [orig_travel[t] for t in T],
        "Optimized": [opt_travel[t] for t in T],
    })
    comparison["Change"] = comparison["Optimized"] - comparison["Original"]
    comparison = comparison.sort_values("Original", ascending=False).reset_index(drop=True)
    print(comparison.to_string(index=False))

    print(f"\n--- Summary ---")
    print(f"Worst team's travel reduced: {orig_max:.0f} -> {opt_max:.0f} miles "
          f"(-{orig_max - opt_max:.0f} mi, {(orig_max - opt_max)/orig_max*100:.1f}%)")
    print(f"Total league travel:         {orig_total:.0f} -> {opt_total:.0f} miles "
          f"({opt_total - orig_total:+.0f} mi)")
else:
    print(f"No solution found. Status: {model.status}")
# Out:
# Optimized max travel: 20736 miles
# Optimized total:      225714 miles
#
#                  Team     Original    Optimized       Change
# Golden State Warriors 23091.131210 20736.183941 -2354.947269
#          Phoenix Suns 18807.376318 13661.445244 -5145.931074
#    Los Angeles Lakers 18613.244566 20714.984863  2101.740297
#        Boston Celtics 18447.583617 20024.430451  1576.846833
#       New York Knicks 18116.178768 18125.742735     9.563967
#    Philadelphia 76ers 16054.857128 15779.236258  -275.620871
#      Dallas Mavericks 14683.587918 11650.344937 -3033.242981
#         Brooklyn Nets 14015.298523 16998.240160  2982.941637
#            Miami Heat 13908.492501 13091.876377  -816.616124
#       Toronto Raptors 12090.280066 12627.491800   537.211734
#        Denver Nuggets 11552.046780 12585.574343  1033.527562
#       Houston Rockets 10505.039230  9829.530181  -675.509049
#   Cleveland Cavaliers 10024.201017 14065.255550  4041.054533
#       Milwaukee Bucks  8793.534951  9264.704249   471.169297
#         Atlanta Hawks  7896.706367  7896.706367     0.000000
#         Chicago Bulls  7853.626170  8661.994619   808.368449
#
# --- Summary ---
# Worst team's travel reduced: 23091 -> 20736 miles (-2355 mi, 10.2%)
# Total league travel:         224453 -> 225714 miles (+1261 mi)

# %% [markdown]
# ### Conclusions on Q4
#
# The minimax model makes the worst-traveled team travel **10.2% less**, from **23,091 miles to 20,736 miles**. This is done by changing the matchups in the original schedule's fixed home/away calendar. The total amount of travel in the league hasn't changed much, which is what a minimax objective is supposed to do: it spreads travel out fairly instead of cutting it down everywhere. Travel is moved from teams on the West Coast that are already busy (Golden State, LA Lakers, Phoenix) to teams that have extra money in their original travel budget (Cleveland, Toronto, Dallas).
